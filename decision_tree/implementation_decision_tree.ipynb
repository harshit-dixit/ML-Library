# %%
"""
This is a DECISION TREE CLASSIFIER module.
   
To use this module - 
   >> import decision_tree as dt

1. Create an object
   >> tree = dt.decision_tree ( matrix of m rows with last column as label )
   Every element of a column should be of same type.
 
2. Train your model
   >> root_node = tree.build_tree()
   This function returns the main root node of the tree.
   
4. Predict values-
   >> y_predict = tree.predict( root_node , test matrix of m rows with feature columns )
   For predicting single example -
   >> y_predict = tree.predict_row( root_node , test row )

5. Accuracy  can be determined by -
   >> accuracy = tree.accuracy(root_node , matrix of m rows with last column as label )

6. A rough print of the tree can be done by -
   >> print_node( root_node )
   
   
"""
# Out:
# '\nThis is a DECISION TREE CLASSIFIER module.\n   \nTo use this module - \n   >> import decision_tree as dt\n\n1. Create an object\n   >> tree = dt.decision_tree ( matrix of m rows with last column as label )\n   Every element of a column should be of same type.\n \n2. Train your model\n   >> root_node = tree.build_tree()\n   This function returns the main root node of the tree.\n   \n4. Predict values-\n   >> y_predict = tree.predict( root_node , test matrix of m rows with feature columns )\n   For predicting single example -\n   >> y_predict = tree.predict_row( root_node , test row )\n\n5. Accuracy  can be determined by -\n   >> accuracy = tree.accuracy(root_node , matrix of m rows with last column as label )\n\n6. A rough print of the tree can be done by -\n   >> print_node( root_node )\n   \n   \n'

# %%
import numpy as np
import decision_tree as dt
import pandas as pd
# Out:
# Traceback (most recent call last):
#
#   File "C:\Lab\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "C:\Users\91983\AppData\Local\Temp/ipykernel_4624/1974827311.py", line 2, in <module>
#     import decision_tree as dt
#
#   File "C:\Users\91983\Desktop\ml_library\decision_tree\decision_tree.py", line 104
#     print Node[0]
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(Node[0])?

# %%
# importing data   - X_data contains features columns and labels as the last column

file_data = pd.read_csv('cancer.txt',header=None)
X = np.array(file_data.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4624/2842248664.py in <module>
#       1 # importing data   - X_data contains features columns and labels as the last column
#       2
# ----> 3 file_data = pd.read_csv('cancer.txt',header=None)
#       4 X = np.array(file_data.values)
#
# NameError: name 'pd' is not defined

# %%
# shuffling and dividing data into training and test set

X_data = np.take(X,np.random.rand(X.shape[0]).argsort(),axis=0,out=X)
X_data = X_data[:,1:]
m = np.shape(X_data)[0]

X_train = X_data[0:int(0.7*m),:]
X_test = X_data[int(0.7*m):,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4624/2086376368.py in <module>
#       1 # shuffling and dividing data into training and test set
#       2
# ----> 3 X_data = np.take(X,np.random.rand(X.shape[0]).argsort(),axis=0,out=X)
#       4 X_data = X_data[:,1:]
#       5 m = np.shape(X_data)[0]
#
# NameError: name 'X' is not defined

# %%
# creating object

tree = dt.decision_tree(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4624/1048082010.py in <module>
#       1 # creating object
#       2
# ----> 3 tree = dt.decision_tree(X_train)
#
# NameError: name 'dt' is not defined

# %%
# training model

root_node = tree.build_tree()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4624/1147677714.py in <module>
#       1 # training model
#       2
# ----> 3 root_node = tree.build_tree()
#
# AttributeError: module 'sklearn.tree' has no attribute 'build_tree'

# %%
# testing model using the root_node

predicted_values = tree.predict( root_node,X_test )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4624/4003333144.py in <module>
#       1 # testing model using the root_node
#       2
# ----> 3 predicted_values = tree.predict( root_node,X_test )
#
# AttributeError: module 'sklearn.tree' has no attribute 'predict'

# %%
# checking accuracy on test data with the root_node

print tree.accuracy( root_node,X_test ),'%'
# Out:
#   File "C:\Users\91983\AppData\Local\Temp/ipykernel_4624/2747449738.py", line 3
#     print tree.accuracy( root_node,X_test ),'%'
#           ^
# SyntaxError: invalid syntax

# %%
# comparing acuracy with sklearn

from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit( X_train[:,0:np.shape(X_train)[1]-1] ,X_train[:,np.shape(X_train)[1]-1:np.shape(X_train)[1]] )
predict = clf.predict ( X_test[:,0:np.shape(X_test)[1]-1]  )
temp = (predict==X_test[:,np.shape(X_test)[1]-1:np.shape(X_test)[1]].flatten()).astype(int)
print (sum(temp)*100.0)/len(temp)
# Out:
# 78.0952380952381
